# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import PySulfSat as ss
import Thermobar as pt

# %%
plt.style.use("seaborn-colorblind")
plt.rcParams["font.family"] = 'arial'
plt.rcParams["font.size"] =12
plt.rcParams["mathtext.default"] = "regular"
plt.rcParams["mathtext.fontset"] = "dejavusans"
plt.rcParams['patch.linewidth'] = 1
plt.rcParams['axes.linewidth'] = 1
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 6 # Sets length of ticks
plt.rcParams["ytick.major.size"] = 4 # Sets length of ticks
plt.rcParams["ytick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["xtick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["axes.titlesize"] = 14 # Overall title
plt.rcParams["axes.labelsize"] = 14 # Axes labels

# %% [markdown]
# ## Loading 2018 melt inclusion data

# %%
# Loading 2018 melt inclusion data
All2018_MI=pd.read_excel('Supporting_Information_2.xlsx', sheet_name="Wieser_Ol_Hosted_MI_2018")

JustF8_MI=(All2018_MI['Sample number']=="LL4")|(All2018_MI['Sample number']=="LL7")|(All2018_MI['Sample number']=="LL8")
F8_MI=All2018_MI.loc[JustF8_MI].reset_index(drop=True)
LL4_MI=F8_MI['Sample number']=="LL4"
LL7_MI=F8_MI['Sample number']=="LL7"
LL8_MI=F8_MI['Sample number']=="LL8"

# Loading 2018 matrix glass
All2018_MG=pd.read_excel('Supporting_Information_2.xlsx', sheet_name="Wieser_MatrixGlass_2018")
JustF8_MG=(All2018_MG['Sample number']=="LL4")|(All2018_MG['Sample number']=="LL7")|(All2018_MG['Sample number']=="LL8")
F8_MG=All2018_MG.loc[JustF8_MG]

grad=130
inter=-415

S_Degass_Lim=grad*F8_MI['FeO_MI EPMA']+inter
Degass=F8_MI['S_MI EPMA (ppm)']<S_Degass_Lim
Undegass=(F8_MI['S_MI EPMA (ppm)']>=S_Degass_Lim)
Degassed_Wieser=F8_MI.loc[F8_MI['S_MI EPMA (ppm)']<S_Degass_Lim]
Undegassed_Wieser=F8_MI.loc[(F8_MI['S_MI EPMA (ppm)']>=S_Degass_Lim)]

Has_Sulf_Wieser=F8_MI['S_Sulf']>0

# %% [markdown]
# ## Making dataframe for raw data

# %%
df_Raw=pd.DataFrame(data={'SiO2_Liq': F8_MI['SiO2_MI EPMA'],
                         'TiO2_Liq': F8_MI['TiO2_MI EPMA'],
                         'MgO_Liq': F8_MI['MgO_MI EPMA'],
                          'FeOt_Liq': F8_MI['FeO_MI EPMA'],
                            'MnO_Liq': F8_MI['MnO_MI EPMA'],
                           'CaO_Liq': F8_MI['CaO_MI EPMA'],
                           'K2O_Liq': F8_MI['K2O_MI EPMA'],
                           'Na2O_Liq': F8_MI['Na2O_MI EPMA'],
                           'Al2O3_Liq': F8_MI['Al2O3_MI EPMA'],
                          'P2O5_Liq': F8_MI['P2O5_MI EPMA'],
                          'H2O_Liq': F8_MI['H2O_MI SIMS'],
                          'Cu_Liq': F8_MI['Cu_ppm_m65 LAICPMS'],
                          'Ni_Liq':F8_MI['Ni_ppm_m60 LAICPMS'],
                        'T_K': 20.1*F8_MI['MgO_MI EPMA']+1014+273.15,
                          'P_kbar': F8_MI['SaturationP_bars_VESIcal']/1000 
                         }).reset_index(drop=True)
#df_Raw['P_kbar'].loc[df_Raw['P_kbar']<0.001]=0.5

# %% [markdown]
# ## Estimating Ni contents
# - For PEC-corrected, we infer Ni contents using a Petrolog model from Wieser et al. (2020), to express Ni as a function of MgO content

# %%
Petr=pd.read_excel('Supporting_Information_2.xlsx', sheet_name='Petrolog_Wieser2020')
plt.plot(Petr['MgO_melt'], Petr['Ni_melt'], 'ok')
Pf = np.poly1d(np.polyfit(Petr['MgO_melt'], Petr['Ni_melt'],
                          10))
Px = np.linspace(4, 17, 101)
Py = Pf(Px)
plt.plot(Px, Py, '-r')

# %% [markdown]
# ## Estimating Cu contents

# %%
plt.plot(Petr['MgO_melt'], Petr['Cu_melt'], 'ok')
Pf_Cu = np.poly1d(np.polyfit(Petr['MgO_melt'], Petr['Cu_melt'],
                          10))
Px = np.linspace(4, 17, 101)
Py_Cu = Pf_Cu(Px)
plt.plot(Px, Py_Cu, '-r')

# %%
df_PEC=pd.DataFrame(data={'SiO2_Liq': F8_MI['SiO2_MI_PEC EPMA'],
                         'TiO2_Liq': F8_MI['TiO2_MI_PEC EPMA'],
                         'MgO_Liq': F8_MI['MgO_MI_PEC EPMA'],
                          'FeOt_Liq': F8_MI['FeO_MI_PEC EPMA'],
                            'MnO_Liq': F8_MI['MnO_MI_PEC EPMA'],
                           'CaO_Liq': F8_MI['CaO_MI_PEC EPMA'],
                           'K2O_Liq': F8_MI['K2O_MI_PEC EPMA'],
                           'Na2O_Liq': F8_MI['Na2O_MI_PEC EPMA'],
                           'Al2O3_Liq': F8_MI['Al2O3_MI_PEC EPMA'],
                          'P2O5_Liq': F8_MI['P2O5_MI_PEC EPMA'],
                          'H2O_Liq': F8_MI['H2O'],
                          'Cu_Liq': Pf_Cu(F8_MI['MgO_MI_PEC EPMA']),
                          'Ni_Liq': Pf(F8_MI['MgO_MI_PEC EPMA']),
                        'T_K': 20.1*F8_MI['MgO_MI_PEC EPMA']+1014+273.15,
                          'P_kbar': F8_MI['SaturationP_bars_VESIcal']/1000 
                         }).reset_index(drop=True)

df_Raw_JustFeOChanged=df_Raw.copy()
df_Raw_JustFeOChanged['FeOt_Liq']=F8_MI['FeO_MI_PEC EPMA']

# %%
SCSS_Raw_Smythe_CalcSulf=ss.calculate_Smythe2017_SCSS(df=df_Raw, T_K=df_Raw['T_K'], 
P_kbar=df_Raw['P_kbar'], Fe_FeNiCu_Sulf="Calc_Smythe",
Fe3Fet_Liq=0.15, Ni_Liq=df_Raw['Ni_Liq'], Cu_Liq=df_Raw['Cu_Liq'])

# %% [markdown]
# ## Investigating sensitivity to temperature

# %%
SCSS_Raw_ONeill_FixedSulf_015Fe3_RawTemp=ss.calculate_ONeill2021_SCSS(df=df_Raw, T_K=df_Raw['T_K'], P_kbar=df_Raw['P_kbar'], 
                                   Ni_Liq=df_Raw['Ni_Liq'], Cu_Liq=df_Raw['Cu_Liq'],
                            Fe_FeNiCu_Sulf=0.646, Fe3Fet_Liq=0.15)

SCSS_Raw_ONeill_FixedSulf_015Fe3_PECTemp=ss.calculate_ONeill2021_SCSS(df=df_Raw, T_K=df_PEC['T_K'], P_kbar=df_Raw['P_kbar'], 
                                   Ni_Liq=df_Raw['Ni_Liq'], Cu_Liq=df_Raw['Cu_Liq'],
                            Fe_FeNiCu_Sulf=0.646, Fe3Fet_Liq=0.15)
# Out:
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.

# %% [markdown]
# ## Investigating sensitivity to just melt FeO content

# %%
SCSS_Raw_ONeill_FixedSulf_015Fe3_JustFeO=ss.calculate_ONeill2021_SCSS(df=df_Raw_JustFeOChanged, 
                                        T_K=df_Raw['T_K'], P_kbar=df_Raw['P_kbar'], 
                                   Ni_Liq=df_Raw['Ni_Liq'], Cu_Liq=df_Raw['Cu_Liq'],
                            Fe_FeNiCu_Sulf=0.646, Fe3Fet_Liq=0.15)
SCSS_Raw_ONeill_FixedSulf_015Fe3_JustFeO_RealTemp=ss.calculate_ONeill2021_SCSS(df=df_Raw_JustFeOChanged, 
                                        T_K=df_PEC['T_K'], P_kbar=df_Raw['P_kbar'], 
                                   Ni_Liq=df_Raw['Ni_Liq'], Cu_Liq=df_Raw['Cu_Liq'],
                            Fe_FeNiCu_Sulf=0.646, Fe3Fet_Liq=0.15)
# Out:
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.

# %% [markdown]
# ## Real difference

# %%
SCSS_PEC_ONeill_FixedSulf_015Fe3_RawTemp=ss.calculate_ONeill2021_SCSS(df=df_PEC, T_K=df_Raw['T_K'], P_kbar=df_PEC['P_kbar'], 
                                   Ni_Liq=df_PEC['Ni_Liq'], Cu_Liq=df_PEC['Cu_Liq'],
                            Fe_FeNiCu_Sulf=0.646, Fe3Fet_Liq=0.15)

SCSS_PEC_ONeill_FixedSulf_015Fe3_RealTemp=ss.calculate_ONeill2021_SCSS(df=df_PEC, T_K=df_PEC['T_K'], P_kbar=df_PEC['P_kbar'], 
                                   Ni_Liq=df_PEC['Ni_Liq'], Cu_Liq=df_PEC['Cu_Liq'],
                            Fe_FeNiCu_Sulf=0.646, Fe3Fet_Liq=0.15)
# Out:
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.

# %%
plt.plot(F8_MI['Amount  PEC (%)'], 
        SCSS_Raw_ONeill_FixedSulf_015Fe3_RawTemp['SCSS2_ppm']
         -SCSS_Raw_ONeill_FixedSulf_015Fe3_PECTemp['SCSS2_ppm'], 'oy',
        label='Just FeOt changed');


plt.plot(F8_MI['Amount  PEC (%)'], 
        SCSS_Raw_ONeill_FixedSulf_015Fe3_RawTemp['SCSS2_ppm']
         -SCSS_Raw_ONeill_FixedSulf_015Fe3_JustFeO['SCSS2_ppm'], 'og',
        label='Just FeOt changed');

plt.plot(F8_MI['Amount  PEC (%)'], 
        SCSS_Raw_ONeill_FixedSulf_015Fe3_RawTemp['SCSS2_ppm']
         -SCSS_Raw_ONeill_FixedSulf_015Fe3_JustFeO_RealTemp['SCSS2_ppm'], 'oc',
        label='Just FeOt changed');

plt.plot(F8_MI['Amount  PEC (%)'], 
        SCSS_Raw_ONeill_FixedSulf_015Fe3_RawTemp['SCSS2_ppm']
         -SCSS_PEC_ONeill_FixedSulf_015Fe3_RawTemp['SCSS2_ppm'], 'ok',
         label='Major elements changed, T the same');

plt.plot(F8_MI['Amount  PEC (%)'], 
        SCSS_Raw_ONeill_FixedSulf_015Fe3_RawTemp['SCSS2_ppm']
         -SCSS_PEC_ONeill_FixedSulf_015Fe3_RealTemp['SCSS2_ppm'], 'or',
        label='Major elements and T changed');
plt.grid(color = 'k', linestyle = '--', linewidth = 1, alpha = 0.1)

# %%
plt.plot(F8_MI['Amount  PEC (%)'], F8_MI['MgO_MI_PEC EPMA']-F8_MI['MgO_MI EPMA'], 'ok')
plt.plot(F8_MI['Amount  PEC (%)'], F8_MI['FeO_MI_PEC EPMA']-F8_MI['FeO_MI EPMA'], 'or')
plt.grid(color = 'k', linestyle = '--', linewidth = 1, alpha = 0.1)

# %%
plt.plot(F8_MI['Amount  PEC (%)'], (F8_MI['MgO_MI_PEC EPMA']*20.1+1014)
         -(F8_MI['MgO_MI EPMA']*20.1+1014), 'ok')
plt.grid(color = 'k', linestyle = '--', linewidth = 1, alpha = 0.1)

# %% [markdown]
# ## Calculated and inputted sulfide compositions

# %%
SCSS_Raw_ONeill_CalcFe3=ss.calculate_ONeill2021_SCSS(df=df_Raw, T_K=df_Raw['T_K'], P_kbar=df_Raw['P_kbar'], 
                                   Ni_Liq=df_Raw['Ni_Liq'], Cu_Liq=df_Raw['Cu_Liq'],
                            Fe_FeNiCu_Sulf="Calc_ONeill", Fe3Fet_Liq="Calc_ONeill")

SCSS_Raw_ONeill_015Fe3=ss.calculate_ONeill2021_SCSS(df=df_Raw, T_K=df_Raw['T_K'], P_kbar=df_Raw['P_kbar'], 
                                   Ni_Liq=df_Raw['Ni_Liq'], Cu_Liq=df_Raw['Cu_Liq'],
                            Fe_FeNiCu_Sulf="Calc_ONeill", Fe3Fet_Liq=0.15)
SCSS_Raw_ONeill_FixedSulf_Fe3=ss.calculate_ONeill2021_SCSS(df=df_Raw, T_K=df_Raw['T_K'], P_kbar=df_Raw['P_kbar'], 
                                   Ni_Liq=df_Raw['Ni_Liq'], Cu_Liq=df_Raw['Cu_Liq'],
                            Fe_FeNiCu_Sulf=0.646, Fe3Fet_Liq=0.15)
SCSS_PEC_ONeill_CalcFe3=ss.calculate_ONeill2021_SCSS(df=df_PEC, T_K=df_PEC['T_K'], P_kbar=df_PEC['P_kbar'], 
                                   Ni_Liq=df_PEC['Ni_Liq'], Cu_Liq=df_PEC['Cu_Liq'],
                            Fe_FeNiCu_Sulf="Calc_ONeill", Fe3Fet_Liq="Calc_ONeill")

SCSS_PEC_ONeill_FixedSulf_015Fe3=ss.calculate_ONeill2021_SCSS(df=df_PEC, T_K=df_PEC['T_K'], P_kbar=df_PEC['P_kbar'], 
                                   Ni_Liq=df_PEC['Ni_Liq'], Cu_Liq=df_PEC['Cu_Liq'],
                            Fe_FeNiCu_Sulf=0.646, Fe3Fet_Liq=0.15)
# Out:
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.

# %% [markdown]
# ## 4 way- Using Calc O'Neill and showing ones that don't have sulfides

# %%
F8_MI.columns[F8_MI.columns.str.contains('Amount')]
# Out:
# Index(['Amount  PEC (%)'], dtype='object')

# %% [markdown]
# ## Fig for paper Just ONeill, colored by MgO

# %%
fig, (ax3, ax4) = plt.subplots(1, 2, figsize=(11,5), sharey=True)

# ax3 - Smythe, using calc sulfide composition
vmin=7
vmax=14

ax3.set_title('Visible Sulfide')
s=ax3.scatter(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(Has_Sulf_Wieser)],
           F8_MI['S_MI EPMA (ppm)'].loc[Undegass&(Has_Sulf_Wieser)],
             marker='o', s=50, edgecolors='k', linewidths=0.5,
            c=F8_MI['MgO_MI_PEC EPMA'].loc[Undegass&(Has_Sulf_Wieser)], cmap='hot_r',
vmin = vmin, vmax = vmax, zorder=100)


s=ax3.scatter(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass&(Has_Sulf_Wieser)],
           F8_MI['S_MI EPMA (ppm)'].loc[Degass&(Has_Sulf_Wieser)],
             marker='d', s=50, edgecolors='k', linewidths=0.5,
            c=F8_MI['MgO_MI_PEC EPMA'].loc[Degass&(Has_Sulf_Wieser)], cmap='hot_r',
vmin = vmin, vmax = vmax, zorder=100)

# ax3.errorbar(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass&Has_Sulf_Wieser],
#          F8_MI['S_MI EPMA (ppm)'].loc[Degass&Has_Sulf_Wieser], yerr=0,
#             xerr=0,
#             fmt='.', ms=0, ecolor='grey', elinewidth=0.8, capsize=3)



# ax4- ones without a sulfide
####################################################################

ax4.set_title('No Visible Sulfide')
s=ax4.scatter(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)],
           F8_MI['S_MI EPMA (ppm)'].loc[Undegass&(~Has_Sulf_Wieser)],
             marker='s', s=30, edgecolors='k', linewidths=0.5,
            c=F8_MI['MgO_MI_PEC EPMA'].loc[Undegass&(~Has_Sulf_Wieser)], cmap='hot_r',
vmin = vmin, vmax = vmax, zorder=1)


s=ax4.scatter(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass&(~Has_Sulf_Wieser)],
           F8_MI['S_MI EPMA (ppm)'].loc[Degass&(~Has_Sulf_Wieser)],
             marker='d', s=50, edgecolors='k', linewidths=0.5,
            c=F8_MI['MgO_MI_PEC EPMA'].loc[Degass&(~Has_Sulf_Wieser)], cmap='hot_r',
vmin = vmin, vmax = vmax, zorder=100)

# ax4.plot(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)&Below_Line],
#            F8_MI['S_MI EPMA (ppm)'].loc[Undegass&(~Has_Sulf_Wieser)&Below_Line], '.g')

# ax4.errorbar(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass&(~Has_Sulf_Wieser)],
#          F8_MI['S_MI EPMA (ppm)'].loc[Degass&(~Has_Sulf_Wieser)], yerr=0,
#             xerr=0,
#             fmt='.', ms=0, ecolor='grey', elinewidth=0.8, capsize=3)


S6_20_Corr=1/(1-0.2)
ax4.plot([400, 1400], [400, 1400], '-k')
ax3.plot([400, 1400], [400, 1400], '-k')
ax4.plot([400/S6_20_Corr, 1400/S6_20_Corr], [400, 1400], ':k')
ax3.plot([400/S6_20_Corr, 1400/S6_20_Corr], [400, 1400], ':k')

#ax4.plot([400/S6_10_Corr, 1400/S6_10_Corr], [400, 1400], '-r')
# ax3.annotate("Oversaturated", xy=(0.1, 0.8), xycoords="axes fraction", fontsize=12)
# ax3.annotate("Undersaturated", xy=(0.1, 0.05), xycoords="axes fraction", fontsize=12)

# ax4.annotate("Oversaturated", xy=(0.1, 0.8), xycoords="axes fraction", fontsize=12)
# ax4.annotate("Undersaturated", xy=(0.1, 0.02), xycoords="axes fraction", fontsize=12)

ax4.set_xlabel('SCSS$^{2-}$ ONeill (2021)')
ax4.set_ylabel('Measured S (ppm)')
ax3.set_xlabel('SCSS$^{2-}$ ONeill (2021)')
ax3.set_ylabel('Measured S (ppm)')
ax4.yaxis.set_tick_params(which='both', labelbottom=True)
fig.colorbar(s, ax=ax3, label='PEC-corrected MgO (wt%)')
fig.delaxes(fig.axes[2])

fig.colorbar(s, ax=ax4, label='PEC-corrected MgO (wt%)')

fig.tight_layout()
fig.savefig('SCSS_Ones_With_Sulf_ONeill.png', dpi=300)

# %% [markdown]
# ## SCSS colored by PEC Amount

# %%
fig, (ax3, ax4) = plt.subplots(1, 2, figsize=(11,5), sharey=True)

# ax3 - Smythe, using calc sulfide composition
vmin=-5
vmax=35

#ax3.set_title('Visible Sulfide')
s=ax3.scatter(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(Has_Sulf_Wieser)],
           F8_MI['S_MI EPMA (ppm)'].loc[Undegass&(Has_Sulf_Wieser)],
             marker='o', s=50, edgecolors='k', linewidths=0.5,
            c=F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)], cmap='hot_r',
vmin = vmin, vmax = vmax, zorder=100)


s=ax3.scatter(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass&(Has_Sulf_Wieser)],
           F8_MI['S_MI EPMA (ppm)'].loc[Degass&(Has_Sulf_Wieser)],
             marker='d', s=50, edgecolors='k', linewidths=0.5,
            c=F8_MI['Amount  PEC (%)'].loc[Degass&(Has_Sulf_Wieser)], cmap='hot_r',
vmin = vmin, vmax = vmax, zorder=100)

# ax3.errorbar(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass&Has_Sulf_Wieser],
#          F8_MI['S_MI EPMA (ppm)'].loc[Degass&Has_Sulf_Wieser], yerr=0,
#             xerr=0,
#             fmt='.', ms=0, ecolor='grey', elinewidth=0.8, capsize=3)



# ax4- ones without a sulfide
####################################################################

#ax4.set_title('No Visible Sulfide')
s=ax4.scatter(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)],
           F8_MI['S_MI EPMA (ppm)'].loc[Undegass&(~Has_Sulf_Wieser)],
             marker='s', s=30, edgecolors='k', linewidths=0.5,
            c=F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)], cmap='hot_r',
vmin = vmin, vmax = vmax, zorder=1)


s=ax4.scatter(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass&(~Has_Sulf_Wieser)],
           F8_MI['S_MI EPMA (ppm)'].loc[Degass&(~Has_Sulf_Wieser)],
             marker='d', s=50, edgecolors='k', linewidths=0.5,
            c=F8_MI['Amount  PEC (%)'].loc[Degass&(~Has_Sulf_Wieser)], cmap='hot_r',
vmin = vmin, vmax = vmax, zorder=100)

# ax4.plot(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)&Below_Line],
#            F8_MI['S_MI EPMA (ppm)'].loc[Undegass&(~Has_Sulf_Wieser)&Below_Line], '.g')

# ax4.errorbar(SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass&(~Has_Sulf_Wieser)],
#          F8_MI['S_MI EPMA (ppm)'].loc[Degass&(~Has_Sulf_Wieser)], yerr=0,
#             xerr=0,
#             fmt='.', ms=0, ecolor='grey', elinewidth=0.8, capsize=3)


S6_20_Corr=1/(1-0.2)
ax4.plot([400, 1400], [400, 1400], '-k')
ax3.plot([400, 1400], [400, 1400], '-k')
ax4.plot([400/S6_20_Corr, 1400/S6_20_Corr], [400, 1400], ':k')
ax3.plot([400/S6_20_Corr, 1400/S6_20_Corr], [400, 1400], ':k')

#ax4.plot([400/S6_10_Corr, 1400/S6_10_Corr], [400, 1400], '-r')
# ax3.annotate("Oversaturated", xy=(0.1, 0.8), xycoords="axes fraction", fontsize=12)
# ax3.annotate("Undersaturated", xy=(0.1, 0.05), xycoords="axes fraction", fontsize=12)

# ax4.annotate("Oversaturated", xy=(0.1, 0.8), xycoords="axes fraction", fontsize=12)
# ax4.annotate("Undersaturated", xy=(0.1, 0.02), xycoords="axes fraction", fontsize=12)

ax4.set_xlabel('SCSS$^{2-}$ ONeill (2021)')
ax4.set_ylabel('Measured S (ppm)')
ax3.set_xlabel('SCSS$^{2-}$ ONeill (2021)')
ax3.set_ylabel('Measured S (ppm)')
ax4.yaxis.set_tick_params(which='both', labelbottom=True)
fig.colorbar(s, ax=ax3, label='PEC-corrected MgO (wt%)')
fig.delaxes(fig.axes[2])

fig.colorbar(s, ax=ax4, label='Amount of PEC (%)')

fig.tight_layout()
fig.savefig('SCSS_Ones_With_Sulf_ONeill_PEc.png', dpi=300)

# %% [markdown]
# ## Fig for paper - Delta SCSS against PEC

# %%
Below_Line=(0.9*SCSS_Raw_ONeill_015Fe3['SCSS2_ppm']>
           F8_MI['S_MI EPMA (ppm)'])

# %%
Ulu_MI=pd.read_excel('Wieser_Data_Formatted.xlsx', sheet_name="Ulu_MIs")
Ulu_MI=Ulu_MI.loc[Ulu_MI['PEC amount']<0]
Ulu_MG=pd.read_excel('Wieser_Data_Formatted.xlsx', sheet_name="Ulu_MG")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 Ulu_MI=pd.read_excel('Wieser_Data_Formatted.xlsx', sheet_name="Ulu_MIs")
#       2 Ulu_MI=Ulu_MI.loc[Ulu_MI['PEC amount']<0]
#       3 Ulu_MG=pd.read_excel('Wieser_Data_Formatted.xlsx', sheet_name="Ulu_MG")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1376, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1374     ext = "xls"
#    1375 else:
# -> 1376     ext = inspect_excel_format(
#    1377         content_or_path=path_or_buffer, storage_options=storage_options
#    1378     )
#    1379     if ext is None:
#    1380         raise ValueError(
#    1381             "Excel file format cannot be determined, you must specify "
#    1382             "an engine manually."
#    1383         )
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1250, in inspect_excel_format(content_or_path, storage_options)
#    1247 if isinstance(content_or_path, bytes):
#    1248     content_or_path = BytesIO(content_or_path)
# -> 1250 with get_handle(
#    1251     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252 ) as handle:
#    1253     stream = handle.handle
#    1254     stream.seek(0)
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:798, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#    (...)
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
# --> 798         handle = open(handle, ioargs.mode)
#     799     handles.append(handle)
#     801 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Wieser_Data_Formatted.xlsx'

# %% [markdown]
# ## Loading in models from script S_Cu_Ni_Removal_Model.ipynb

# %%
Cu_Evolution=pd.read_excel('Cu_PEC_model.xlsx', sheet_name="Sheet1")

# %%
plt.plot(Ulu_MI['FeOt'], Ulu_MI['S_RAW'], '.c')
S_Degass_Ulu=grad*Ulu_MI['FeOt']+inter+70
plt.plot(Ulu_MI['FeOt'],S_Degass_Ulu )
Degass_Ulu=S_Degass_Ulu>Ulu_MI['S_RAW']
Undegass_Ulu=~Degass_Ulu
plt.plot(Ulu_MI['FeOt'].loc[Undegass_Ulu], Ulu_MI['S_RAW'].loc[Undegass_Ulu], '.r')

# %%
Cu_Evolution.head()
# Out:
#    Unnamed: 0  Amount PEC  Cu_Liq_req  Cu_Liq_Frac  S_Liq_req_calc  \
# 0           0    0.000000  189.900000   189.900000     1200.000000
# 1           1    1.034483  171.998615   172.011915     1181.478861
# 2           2    2.068966  155.132295   156.284562     1162.955570
# 3           3    3.103448  139.568270   142.451330     1144.430126
# 4           4    4.137931  124.504991   130.119541     1125.902529
#
#    Cu_Liq_1400_req  Cu_Liq_1400  Cu_Liq_1600_req  Cu_Liq_1600   S_Liq_Frac
# 0       189.900000   189.900000       189.900000   189.900000  1200.000000
# 1       174.465518   174.465518       172.259016   172.259016  1181.478861
# 2       161.540115   160.285503       157.485551   156.051708  1162.956646
# 3       150.511930   147.257995       144.880334   141.161552  1144.433355
# 4       140.968057   135.289323       133.971474   127.481493  1125.908987

# %%
fig, ((ax3a),(ax3b)) = plt.subplots(1, 2, figsize=(6,5),gridspec_kw={'width_ratios': [4.2, 0.5]})
plt.subplots_adjust(wspace=0, hspace=0)
ax3a.plot(Cu_Evolution['Amount PEC'], Cu_Evolution['Cu_Liq_Frac'], '-r')
ax3a.plot(Cu_Evolution['Amount PEC'], Cu_Evolution['Cu_Liq_1400_req'], ':r')
ax3a.plot(Cu_Evolution['Amount PEC'], Cu_Evolution['Cu_Liq_1600_req'], '--r')

# ax3a.plot(-Ulu_MI['PEC amount'].loc[Undegass_Ulu], Ulu_MI['Cu_ppm_m65'].loc[Undegass_Ulu], 'sc', ms=3)
# Ulu_Has_Sulf=Ulu_MI['Sulfide?']=="Y"
# ax3a.plot(-Ulu_MI['PEC amount'].loc[Ulu_Has_Sulf&Undegass_Ulu], 
#           Ulu_MI['Cu_ppm_m65'].loc[Ulu_Has_Sulf&Undegass_Ulu], 'o', mfc='white', mec='c')


ax3a.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)],
         F8_MI['Cu_ppm_m65 LAICPMS'].loc[Undegass&(~Has_Sulf_Wieser)],  
         'sk')

ax3a.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)],
         F8_MI['Cu_ppm_m65 LAICPMS'].loc[Undegass&(Has_Sulf_Wieser)],  
         'ok', mfc='white')

ax3a.plot(F8_MI['Amount  PEC (%)'].loc[Degass],
         F8_MI['Cu_ppm_m65 LAICPMS'].loc[Degass],  
         'dk', mfc='white')


# ax3b.hist(Ulu_MG['Cu_ppm_m65'],alpha=0.7,density=1,
#           orientation='horizontal',color='cyan', ec='k')
ax3b.hist(F8_MG['Cu_ppm_m65 LAICPMS'],alpha=0.7,density=1,
          orientation='horizontal',color='white', ec='k')
ax3a.plot([-5, 35],
    [np.min(F8_MG['Cu_ppm_m65 LAICPMS']), np.min(F8_MG['Cu_ppm_m65 LAICPMS'])],
                        '-k', lw=0.5)
ax3a.plot([-5, 35],
    [np.max(F8_MG['Cu_ppm_m65 LAICPMS']), np.max(F8_MG['Cu_ppm_m65 LAICPMS'])],
                        '-k', lw=0.5)

# ax3a.plot([-5, 35],
#     [np.min(Ulu_MG['Cu_ppm_m65']), np.min(Ulu_MG['Cu_ppm_m65'])],
#                         '-c', lw=0.5)
# ax3a.plot([-5, 35],
#     [np.max(Ulu_MG['Cu_ppm_m65']), np.max(Ulu_MG['Cu_ppm_m65'])],
#                         '-c', lw=0.5)
ax3b.axes.get_xaxis().set_visible(False)
ax3b.axes.get_yaxis().set_visible(False)
ax3b.set_ylim([0, 200])
ax3a.set_ylim([0, 200])
ax3b.axis("off")
ax3a.set_xlim([-3, 33])
ax3a.set_xlabel('Amount of PEC (%)')
ax3a.set_ylabel('Cu (ppm)')
fig.savefig('Cu_Frac_Systematics.png', dpi=300, transparent=True)

# %%
fig, ((ax3a),(ax3b)) = plt.subplots(1, 2, figsize=(6,5),gridspec_kw={'width_ratios': [4.2, 0.5]})
plt.subplots_adjust(wspace=0, hspace=0)

ax3b.axes.get_xaxis().set_visible(False)
ax3b.axes.get_yaxis().set_visible(False)
ax3a.plot(-Ulu_MI['PEC amount'].loc[Undegass_Ulu], Ulu_MI['Cu_ppm_m65'].loc[Undegass_Ulu], 'sc', ms=3)
ax3a.plot(-Ulu_MI['PEC amount'].loc[~Undegass_Ulu], Ulu_MI['Cu_ppm_m65'].loc[~Undegass_Ulu], 'dc', mfc='None', ms=4)

Ulu_Has_Sulf=Ulu_MI['Sulfide?']=="Y"
ax3a.plot(-Ulu_MI['PEC amount'].loc[Ulu_Has_Sulf&Undegass_Ulu], 
          Ulu_MI['Cu_ppm_m65'].loc[Ulu_Has_Sulf&Undegass_Ulu], 'o', mfc='white', mec='c')
ax3b.hist(Ulu_MG['Cu_ppm_m65'],alpha=0.7,density=1,
          orientation='horizontal',color='cyan', ec='k')
ax3a.plot([-5, 35],
    [np.min(Ulu_MG['Cu_ppm_m65']), np.min(Ulu_MG['Cu_ppm_m65'])],
                        '-c', lw=0.5)
ax3a.plot([-5, 35],
    [np.max(Ulu_MG['Cu_ppm_m65']), np.max(Ulu_MG['Cu_ppm_m65'])],
                        '-c', lw=0.5)
ax3a.plot(Cu_Evolution['Amount PEC'], Cu_Evolution['Cu_Liq_Frac'], '-r')
ax3a.plot(Cu_Evolution['Amount PEC'], Cu_Evolution['Cu_Liq_1400_req'], ':r')
ax3a.plot(Cu_Evolution['Amount PEC'], Cu_Evolution['Cu_Liq_1600_req'], '--r')

ax3a.set_ylim([0, 200])
ax3b.set_ylim([0, 200])
ax3b.axis("off")
ax3a.set_xlim([-3, 33])

ax3a.set_xlabel('Amount of PEC (%)')
ax3a.set_ylabel('Cu (ppm)')

fig.savefig('Cu_Ulu.png', dpi=300, transparent=True)

# %%
fig, ((ax3a),(ax3b)) = plt.subplots(1, 2, figsize=(8,5),gridspec_kw={'width_ratios': [4.2, 1]})
plt.subplots_adjust(wspace=0, hspace=0)
ax3a.plot(Cu_Evolution['Amount PEC'], Cu_Evolution['Cu_Liq_Frac'], '-r')
ax3a.plot(Cu_Evolution['Amount PEC'], Cu_Evolution['Cu_Liq_1400_req'], ':r')
ax3a.plot(Cu_Evolution['Amount PEC'], Cu_Evolution['Cu_Liq_1600_req'], '--r')


ax3a.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)],
         F8_MI['Cu_ppm_m65 LAICPMS'].loc[Undegass&(~Has_Sulf_Wieser)],  
         'sk')

ax3a.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)],
         F8_MI['Cu_ppm_m65 LAICPMS'].loc[Undegass&(Has_Sulf_Wieser)],  
         'ok', mfc='white')

ax3a.plot(F8_MI['Amount  PEC (%)'].loc[Degass],
         F8_MI['Cu_ppm_m65 LAICPMS'].loc[Degass],  
         'dk', mfc='white')



ax3b.hist(F8_MG['Cu_ppm_m65 LAICPMS'],alpha=0.7,density=1,
          orientation='horizontal',color='white', ec='k')
ax3a.plot([-5, 35],
    [np.min(F8_MG['Cu_ppm_m65 LAICPMS']), np.min(F8_MG['Cu_ppm_m65 LAICPMS'])],
                        '-k', lw=0.5)
ax3a.plot([-5, 35],
    [np.max(F8_MG['Cu_ppm_m65 LAICPMS']), np.max(F8_MG['Cu_ppm_m65 LAICPMS'])],
                        '-k', lw=0.5)

ax3b.axes.get_xaxis().set_visible(False)
ax3b.axes.get_yaxis().set_visible(False)
ax3b.set_ylim([0, 200])
ax3a.set_ylim([0, 200])
ax3b.axis("off")
ax3a.set_xlim([-3, 33])
ax3a.set_xlabel('Amount of PEC (%)')
ax3a.set_ylabel('Cu (ppm)')
fig.savefig('Cu_Frac_Systematics.png', dpi=300, transparent=True)

# %% [markdown]
# ## Sulfur vs Cu

# %%
fig, ((ax3a), (ax4a)) = plt.subplots(1, 2, figsize=(12.9,5))
ax3a.plot(Cu_Evolution['S_Liq_Frac'], Cu_Evolution['Cu_Liq_Frac'], '-r')


ax3a.plot(Cu_Evolution['S_Liq_Frac'], Cu_Evolution['Cu_Liq_Frac'], '-r')
ax3a.plot(Cu_Evolution['S_Liq_Frac'], Cu_Evolution['Cu_Liq_1400_req'], ':r')
ax3a.plot(Cu_Evolution['S_Liq_Frac'], Cu_Evolution['Cu_Liq_1600_req'], '--r')



ax3a.plot(F8_MI['S_MI EPMA (ppm)'].loc[Undegass&(~Has_Sulf_Wieser)],
         F8_MI['Cu_ppm_m65 LAICPMS'].loc[Undegass&(~Has_Sulf_Wieser)],  
         'sk')

ax3a.plot(F8_MI['S_MI EPMA (ppm)'].loc[Undegass&(Has_Sulf_Wieser)],
         F8_MI['Cu_ppm_m65 LAICPMS'].loc[Undegass&(Has_Sulf_Wieser)],  
         'ok', mfc='white')

ax3a.plot(F8_MI['S_MI EPMA (ppm)'].loc[Degass],
         F8_MI['Cu_ppm_m65 LAICPMS'].loc[Degass],  
         'dk', mfc='white')


# ax3a.plot(Ulu_MI['S_RAW'].loc[Ulu_Has_Sulf&Undegass_Ulu], 
#           Ulu_MI['Cu_ppm_m65'].loc[Ulu_Has_Sulf&Undegass_Ulu], 'o', mfc='white', mec='c')

# ax3a.plot(Ulu_MI['S_RAW'].loc[(~Ulu_Has_Sulf)&Undegass_Ulu], 
#           Ulu_MI['Cu_ppm_m65'].loc[(~Ulu_Has_Sulf)&Undegass_Ulu], 's', mfc='c', mec='c')

########################################33

ax4a.plot(-Ulu_MI['PEC amount'].loc[Ulu_Has_Sulf&Undegass_Ulu], 
          Ulu_MI['Se_96_ppm_m80'].loc[Ulu_Has_Sulf&Undegass_Ulu], 'o', mfc='white', mec='c')

ax4a.plot(-Ulu_MI['PEC amount'].loc[(~Ulu_Has_Sulf)&Undegass_Ulu], 
          Ulu_MI['Se_96_ppm_m80'].loc[(~Ulu_Has_Sulf)&Undegass_Ulu], 's', mfc='c', mec='c')

ax4a.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)],
         F8_MI['Se_96_ppm_m80'].loc[Undegass&(~Has_Sulf_Wieser)],  
         'sk')

ax4a.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)],
         F8_MI['Se_96_ppm_m80'].loc[Undegass&(Has_Sulf_Wieser)],  
         'ok', mfc='white')

ax4a.plot(F8_MI['Amount  PEC (%)'].loc[Degass],
         F8_MI['Se_96_ppm_m80'].loc[Degass],  
         'dk', mfc='white')

ax4a.plot(Se_Evolution['Amount PEC'], Se_Evolution['Se_Liq_Brenan_req'], ':b')
ax4a.plot(Se_Evolution['Amount PEC'], Se_Evolution['Se_Liq_Brenan'], '-b')
ax4a.plot(Se_Evolution['Amount PEC'], Se_Evolution['Se_Liq_Patten_req'], ':g')
ax4a.plot(Se_Evolution['Amount PEC'], Se_Evolution['Se_Liq_Patten'], '-g')


ax4a.set_xlabel('Amount of PEC (%)')
ax4a.set_ylabel('Se (ppm)')

ax3a.set_xlabel('S (ppm)')
ax3a.set_ylabel('Cu (ppm)')

plt.subplots_adjust(wspace=0.38, hspace=0)


fig.savefig('Cu_S_Frac_Systematics.png', dpi=300, transparent=True)

# %%
Se_Evolution=pd.read_excel('Se_PEC_model.xlsx', sheet_name="Sheet1")

# %%
np.nanmedian(Ulu_MI['Se_96_ppm_m80'])
# Out:
# 0.2875

# %%
fig, ((ax3a),(ax3b)) = plt.subplots(1, 2, figsize=(8,5),gridspec_kw={'width_ratios': [4.2, 1]})
plt.subplots_adjust(wspace=0, hspace=0)


ax3a.plot(-Ulu_MI['PEC amount'].loc[Ulu_Has_Sulf&Undegass_Ulu], 
          Ulu_MI['Se_96_ppm_m80'].loc[Ulu_Has_Sulf&Undegass_Ulu], 'o', mfc='white', mec='c')

ax3a.plot(-Ulu_MI['PEC amount'].loc[(~Ulu_Has_Sulf)&Undegass_Ulu], 
          Ulu_MI['Se_96_ppm_m80'].loc[(~Ulu_Has_Sulf)&Undegass_Ulu], 's', mfc='c', mec='c')

ax3a.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)],
         F8_MI['Se_96_ppm_m80'].loc[Undegass&(~Has_Sulf_Wieser)],  
         'sk')

ax3a.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)],
         F8_MI['Se_96_ppm_m80'].loc[Undegass&(Has_Sulf_Wieser)],  
         'ok', mfc='white')

ax3a.plot(F8_MI['Amount  PEC (%)'].loc[Degass],
         F8_MI['Se_96_ppm_m80'].loc[Degass],  
         'dk', mfc='white')

ax3a.plot(Se_Evolution['Amount PEC'], Se_Evolution['Se_Liq_Brenan_req'], ':b')
ax3a.plot(Se_Evolution['Amount PEC'], Se_Evolution['Se_Liq_Brenan'], '-b')
ax3a.plot(Se_Evolution['Amount PEC'], Se_Evolution['Se_Liq_Patten_req'], ':r')
ax3a.plot(Se_Evolution['Amount PEC'], Se_Evolution['Se_Liq_Patten'], '-r')


ax3b.axes.get_xaxis().set_visible(False)
ax3b.axes.get_yaxis().set_visible(False)
ax3b.axis("off")

ax3a.set_xlim([-3, 33])
ax3a.set_xlabel('Amount of PEC (%)')
ax3a.set_ylabel('Se (ppm)')
fig.savefig('Se_Frac_Systematics.png', dpi=300, transparent=True)

# %% [markdown]
# ## PEC vs. Sulfur Figure recreating Bristol Seminar

# %%
fig, ((ax2, ax4)) = plt.subplots(1, 2, figsize=(10,5))
Undegass&(~Has_Sulf_Wieser)

ax2.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)],
         SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(Has_Sulf_Wieser)],       
         'o', mec='cornflowerblue', mfc='white')
ax2.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)],
         SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)],       
         's', mec='cornflowerblue', mfc='white')
ax2.plot(F8_MI['Amount  PEC (%)'].loc[Degass],
         SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass],       
         'd', mec='cornflowerblue', mfc='white')

ax2.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)],
         SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'].loc[Undegass&(Has_Sulf_Wieser)],       
         'ok', mfc='white')
ax2.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)],
         SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)],       
         'sk', mfc='white')
ax2.plot(F8_MI['Amount  PEC (%)'].loc[Degass],
         SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'].loc[Degass],       
         'dk', mfc='white')

ax2.set_xlabel('Amount PEC (%)')
ax2.set_ylabel('Modelled SCSS$^{2-}$ (ONeill 2021)')

S_Predicted_Sulf=( (SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'])*F8_MI['Amount  PEC (%)']/100
+ (SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm']-SCSS_Raw_ONeill_015Fe3['SCSS2_ppm']))
ax4.plot([6, 14], [0, 0], '-k', lw=0.2)
 
ax4.errorbar(F8_MI['MgO_MI_PEC EPMA'].loc[Undegass], 
             F8_MI['S_Sulf'].loc[Undegass]-S_Predicted_Sulf.loc[Undegass]
             , xerr=0,
            yerr=0.7*F8_MI['S_Sulf'].loc[Undegass],
            fmt='.', ms=0, ecolor='grey', elinewidth=0.8, capsize=3)  
ax4.plot(F8_MI['MgO_MI_PEC EPMA'].loc[Undegass&LL4_MI], 
        F8_MI['S_Sulf'].loc[Undegass&LL4_MI]-S_Predicted_Sulf.loc[Undegass&LL4_MI], 'ok', mfc='blue')
ax4.plot(F8_MI['MgO_MI_PEC EPMA'].loc[Undegass&LL7_MI], 
        F8_MI['S_Sulf'].loc[Undegass&LL7_MI]
         -S_Predicted_Sulf.loc[Undegass&LL7_MI], 'ok', mfc='orange')
ax4.plot(F8_MI['MgO_MI_PEC EPMA'].loc[Undegass&LL8_MI], 
        F8_MI['S_Sulf'].loc[Undegass&LL8_MI]
         -S_Predicted_Sulf.loc[Undegass&LL8_MI], 'ok', mfc='red')

from matplotlib import patches
rect = patches.Rectangle((11,-1500),2,4000,
                         linewidth=1,edgecolor='r',facecolor='none', label='test',  hatch='///',
                        alpha=0.3)

ax4.set_xlabel('MgO wt% (PEC-corrected)')
ax4.set_ylabel('Measured S in Sulf - Predicted S in sulfide')

# Add the patch to the Axes
ax4.add_patch(rect)
fig.tight_layout()

fig.savefig('SCSS_Changes_PEC.png', dpi=200)

# %% [markdown]
# ## Figure for Marie

# %%
Reg_RawOneill=pt.calculate_R2(F8_MI['Amount  PEC (%)'],
         SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'])
Reg_PEC_ONeill=pt.calculate_R2(F8_MI['Amount  PEC (%)'],
         SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'])

lin_PEC=np.linspace(0, 50, 100)
S_PEC=(np.max(Reg_RawOneill['y_pred']))*(1+lin_PEC/100)
                                  

fig, ((ax2)) = plt.subplots(1, 1, figsize=(10,5))
Undegass&(~Has_Sulf_Wieser)

ax2.plot(lin_PEC, S_PEC, '-r')
# ax2.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)],
#          SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(Has_Sulf_Wieser)],       
#          'o', mec='cornflowerblue', mfc='white')
# ax2.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)],
#          SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)],       
#          's', mec='cornflowerblue', mfc='white')
# ax2.plot(F8_MI['Amount  PEC (%)'].loc[Degass],
#          SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Degass],       
#          'd', mec='cornflowerblue', mfc='white')

ax2.plot(Reg_RawOneill['x_pred'], Reg_RawOneill['y_pred'], '-k')

#ax2.plot(Reg_PEC_ONeill['x_pred'], Reg_PEC_ONeill['y_pred']+100, '-g')

# ax2.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)],
#          SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'].loc[Undegass&(Has_Sulf_Wieser)],       
#          'ok', mfc='white')
# ax2.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)],
#          SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)],       
#          'sk', mfc='white')
# ax2.plot(F8_MI['Amount  PEC (%)'].loc[Degass],
#          SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'].loc[Degass],       
#          'dk', mfc='white')

ax2.set_xlabel('Amount PEC (%)')
ax2.set_ylabel('Modelled SCSS$^{2-}$ (ONeill 2021)')
# Out:
# Text(0, 0.5, 'Modelled SCSS$^{2-}$ (ONeill 2021)')

# %% [markdown]
# ## What is the one blue one with lots of deltaS

# %%
One_to_find=(F8_MI['S_Sulf'].loc[Undegass&LL4_MI]-S_Predicted_Sulf.loc[Undegass&LL4_MI])>1000
F8_filt=F8_MI[Undegass&LL4_MI]
Found=F8_filt.loc[One_to_find]
Found['Amount  PEC (%)']
# Out:
# 99    4.77
# Name: Amount  PEC (%), dtype: float64

# %%
Found['S_Sulf']
# Out:
# 99    1804.262708
# Name: S_Sulf, dtype: float64

# %%
Found['Comment']
# Out:
# 99    LL4_13
# Name: Comment, dtype: object

# %%
Found['FeO_MI EPMA']
# Out:
# 99    10.8212
# Name: FeO_MI EPMA, dtype: float64

# %%
np.max(F8_MI['S_Sulf'].loc[Undegass&LL4_MI]-S_Predicted_Sulf.loc[Undegass&LL4_MI])
# Out:
# 1664.5896183282812

# %% [markdown]
# ## Can we say anything about nucleation

# %%
plt.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(~Has_Sulf_Wieser)],
SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)]-
         SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'].loc[Undegass&(~Has_Sulf_Wieser)],       
         's', mec='cornflowerblue', mfc='white')
plt.plot(F8_MI['Amount  PEC (%)'].loc[Undegass&(Has_Sulf_Wieser)],
SCSS_Raw_ONeill_015Fe3['SCSS2_ppm'].loc[Undegass&(Has_Sulf_Wieser)]-
         SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'].loc[Undegass&(Has_Sulf_Wieser)],       
         'o', mfc='red', mec='k')

# %% [markdown]
# ## Was it sulfide saturated whie it was trapped
# - PEC is defined relative to the mas now. E.g., if you had 70g of melt now, and you have undergone 30% PEC, this means its initial mass is 91 g. Not 100g.
# - First assume no change in the SCSS - The amount of S that goes into the sulfide is the change in the mass of the melt
# - For example, assume initially you have 130g of melt, which holds 1000 ppm of Sulfide. 130*(1000/10^6)=0.13 g of S
# - If you undergo 30% PEC, you now only have 100g of melt remaining. Which can only hold 1000 ppm of Sulfide, so in the melt you have 0.1  g of S. This means you have 0.03 g of S in the sulfide, which relative to the remaining mass of melt is 300 ppm of S.
# - Now say there was a change in the SCSS. So now the melt only holds 500 ppm of Sulfide
# - So the melt portion now has 500 pppm * 100g=0.05 g of S. So you have 0.08 g of S unaccounted. so 800 ppm in the sulfide. 0.05 g of which resulted from the change in the SCSS.
# ## My equation testing
# - So overall equation = SCSS PEC * (amount of PEC/100)
# + (SCSS PEC - SCSS Raw)

# %%
## First, work out S in sulfide due to change in SCSS, as comparing at equvailent passes

# But, also have the changing mass of the inclusion. Initially, was 30% bigger, so had 30% more S thathis
S_Sulf=(1000)*0.3 + (1000-500)
S_Sulf
# Out:
# 800.0

# %% [markdown]
# ## Example 2 -
# - Say we have 800 ppm in the initial melt inclusion, mass of 60 g. So 0.048 g of S
# - Say it underwent 20% PEC, new mass is (X*1.2=60, so Xinit=60/1.2=50)
# - Say the SCSS we measure now is only 600 ppm.
# - S left in melt = 600*50g = 0.03g of S
# - S in sulfide = 0.018 g
# - Equivalent conc in melt = 0.018/50 = 359.9 ppm.

# %%
S_in_Sulf=800*(0.2) + 200
S_in_Sulf
# Out:
# 360.0

# %% [markdown]
# ## Now lets predict it for these melt inclusions

# %%
S_Predicted_Sulf=( (SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm'])*F8_MI['Amount  PEC (%)']/100
+ (SCSS_PEC_ONeill_FixedSulf_015Fe3['SCSS2_ppm']-SCSS_Raw_ONeill_015Fe3['SCSS2_ppm']))
plt.plot([6, 14], [0, 0], '-k', lw=0.2)
 
plt.errorbar(F8_MI['MgO_MI_PEC EPMA'].loc[Undegass], F8_MI['S_Sulf'].loc[Undegass]-S_Predicted_Sulf.loc[Undegass]
             , xerr=0,
            yerr=0.6*F8_MI['S_Sulf'].loc[Undegass],
            fmt='.', ms=0, ecolor='grey', elinewidth=0.8, capsize=3)  
plt.plot(F8_MI['MgO_MI_PEC EPMA'].loc[Undegass], F8_MI['S_Sulf'].loc[Undegass]-S_Predicted_Sulf.loc[Undegass], 'ok')

# %%
# Only plot the ones which have a sulf. 
plt.errorbar(SCSS_Raw_Smythe_CalcSulf['SCSS_non_ideal_ppm_Smythe2017'].loc[Undegass],
         F8_MI['S_MI EPMA (ppm)'].loc[Undegass], yerr=0,
            xerr=SCSS_Raw_Smythe_CalcSulf['SCSS_non_ideal_ppm_Smythe2017_1sigma'].loc[Undegass],
            fmt='.', ms=0, ecolor='grey', elinewidth=0.8, capsize=3)
plt.plot(SCSS_Raw_Smythe_CalcSulf['SCSS_non_ideal_ppm_Smythe2017'].loc[Degass],
         F8_MI['S_MI EPMA (ppm)'].loc[Degass], 'dk', mfc='white')
plt.plot(SCSS_Raw_Smythe_CalcSulf['SCSS_non_ideal_ppm_Smythe2017'].loc[Undegass],
         F8_MI['S_MI EPMA (ppm)'].loc[Undegass], 'ok')


plt.plot([400, 1400], [400, 1400], '-r')
